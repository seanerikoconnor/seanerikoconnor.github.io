# %%
H.<i,j,k>=QuaternionAlgebra(SR, -1, -1)

# %%
H
# Out:
# Quaternion Algebra (-1, -1) with base ring Symbolic Ring

# %%
i * i
# Out:
# -1

# %%
k * k
# Out:
# -1

# %%
var('a1, a2, a3, a4, b1, b2, b3, b4, p1, p2, p3, p4, θ, p, q')
# Out:
# (a1, a2, a3, a4, b1, b2, b3, b4, p1, p2, p3, p4, θ, p, q)

# %%
a = a1 + a2 * i + a3 * j + a4 * k

# %%
b = b1 + b2 * i + b3 * j + b4 * k

# %%
a * b
# Out:
# a1*b1 - a2*b2 - a3*b3 - a4*b4 + ((a1 + a2)*(b1 + b2) - a1*b1 - a2*b2 - (a3 + a4)*(b3 - b4) + a3*b3 - a4*b4)*i + (a3*b1 + a4*b2 + a1*b3 - a2*b4)*j + ((a3 + a4)*(b1 - b2) - a3*b1 + a4*b2 + (a1 + a2)*(b3 + b4) - a1*b3 - a2*b4)*k

# %%
a + b
# Out:
# a1 + b1 + (a2 + b2)*i + (a3 + b3)*j + (a4 + b4)*k

# %%
q = cos(θ/2) + (a1 * i + a2 * j + a3 * k) * sin(θ/2)

# %%
p = p2 * i + p3 * j + p4 * k

# %%
q.inverse()
# Out:
# cos(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2) + (-a1*sin(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2))*i + (-a2*sin(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2))*j + (-a3*sin(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2))*k

# %%
rotate_by_θ = q * p * q.inverse()

# %%
rotate_by_θ
# Out:
# ((2*a1*p2*sin(1/2*θ) + 2*a3*p4*sin(1/2*θ) - (a1*sin(1/2*θ) + cos(1/2*θ))*p2 + (a2*sin(1/2*θ) + a3*sin(1/2*θ))*(p3 - p4))*(a1*sin(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2) - cos(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2)) + (2*a3*p2*sin(1/2*θ) - 2*a1*p4*sin(1/2*θ) - (a2*sin(1/2*θ) + a3*sin(1/2*θ))*p2 + (a1*sin(1/2*θ) + cos(1/2*θ))*(p3 + p4))*(a2*sin(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2) - a3*sin(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2)) - (a1*p2*sin(1/2*θ) - a2*p3*sin(1/2*θ) + a3*p4*sin(1/2*θ) - (a1*sin(1/2*θ) + cos(1/2*θ))*p2 + (a2*sin(1/2*θ) + a3*sin(1/2*θ))*(p3 - p4))*a1*sin(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2) - (a3*p2*sin(1/2*θ) - a1*p4*sin(1/2*θ) + p3*cos(1/2*θ))*a2*sin(1/2*θ)/(a1^2*sin(1/2*θ)^2 + a2^2*sin(1/2*θ)^2 + a3^2*sin(1/2*θ)^2 + cos(1/2*θ)^2) + (a3*p2*sin(1/2*θ) - a
# ...
